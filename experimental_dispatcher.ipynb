# %% [markdown]
# # BrainScaleS-2 Demos — `experimental` state
#
# To work with the latest state of the BSS-2 software and demos, the software version available in this notebook kernel needs to match the version of the jupyter notebooks. Please execute the next cell to update the repository state to the correct version.

# %%
import pynn_brainscales, os, re
version = re.search(r'.*pynn-brainscales-([0-9.a-z_-]+)-[a-z0-9]*/.*', os.path.realpath(pynn_brainscales.__file__)).group(1)
print(f"Resolved software state to {version}. Updating workspace to match version.")
# !git fetch -q origin -t && git checkout jupyter-notebooks-$version .

# %% [markdown]
# Now you can continue with → [our tutorial](./tutorial.ipynb) 🚀
